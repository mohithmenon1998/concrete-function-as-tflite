# %% [markdown]
# Save a concrete function as a tflite model

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/tensorflow-lite-examples/
# Out:
# /content/drive/MyDrive/tensorflow-lite-examples

# %%
import tensorflow as tf

# %%
# load the mobilenet model
model = tf.keras.applications.MobileNetV2(weights='imagenet', input_shape=(224, 224,3))
# Out:
# ...
# 14540800/14536120 [==============================] - 0s 0us/step

# %%
# get the concrete function from the keras model
run_model = tf.function(lambda x: model(x))

# %%
# save the concrete function
concrete_fun = run_model.get_concrete_function(tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

# %%
# save the model
converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_fun])
tflite_model = converter.convert()

# %%
concrete_fun.trainable_variables
# Out:
# (<tf.Variable 'block_14_expand_BN/beta:0' shape=(960,) dtype=float32, numpy=
#  array([ 6.20462358e-01, -1.00453043e+00,  6.74115121e-01,  9.58992422e-01,
#         -1.98849455e-01,  8.66482139e-01, -7.99605906e-01, -1.84816980e+00,
#          2.01695621e-01,  1.48963898e-01,  1.58905268e-01,  1.05885774e-01,
#          1.67112410e+00, -1.02050513e-01, -4.02500093e-01,  5.05951419e-02,
#         -8.00786138e-01,  1.38916838e+00, -5.64922810e-01, -2.14649877e-03,
#          1.56268597e+00,  9.95120704e-02, -9.10766602e-01,  9.96789217e-01,
#          9.64773417e-01, -1.00698745e+00,  1.05996144e+00, -5.52719474e-01,
#          1.58012062e-02, -4.50639352e-02, -5.23148000e-01,  2.87310064e-01,
#          9.96987522e-01, -2.41587892e-01,  7.80712068e-01,  8.82054627e-01,
#          4.31191206e-01,  8.23894203e-01,  5.94168007e-01,  1.16692388e+00,
#          1.19148171e+00,  2.57224023e-01,  7.92459726e-01,  9.21280801e-01,
# ...
